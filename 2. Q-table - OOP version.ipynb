# %% [markdown]
# # Import the agent

# %%
from agents import *

# %% [markdown]
# # Agent setup

# %%
q_agent = RLAgentQTable()
print(q_agent.q_table.shape)
# Out:
# (20, 20, 20, 20, 20, 20, 2, 2, 4)

# %% [markdown]
# # Training the agent

# %%
q_agent.learn()
# Out:
# 100%|██████████| 20000/20000 [03:46<00:00, 88.16it/s]

# %% [markdown]
# # Visualizing results

# %%
q_agent.plot_rewards('out/Q-table approach.png')

# %%
q_agent.plot_successes('out/Q-table approach - successes.png')
